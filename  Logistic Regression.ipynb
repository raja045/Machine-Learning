# %% [markdown]
# # **Project on Logistic Regression**

# %% [markdown]
# ## **Loading the DataSet**

# %%
import pandas as pd

# Load data from GitHub with the raw file link

dataset = pd.read_excel('/content/a_Dataset_CreditScoring.xlsx')

# Display the first few rows of the dataframe
print(df.head())
# Out:
#    TARGET    ID  DerogCnt  CollectCnt  BanruptcyInd  InqCnt06  InqTimeLast  \
# 0       1   582         3           3             0         4          0.0
# 1       1   662        15           9             0         3          1.0
# 2       1   805         0           0             0         1          5.0
# 3       1  1175         8           5             0         6          1.0
# 4       1  1373         3           1             0         9          0.0
#
#    InqFinanceCnt24  TLTimeFirst  TLTimeLast  ...  TL50UtilCnt  TLBalHCPct  \
# 0                5          117          27  ...          3.0      0.9179
# 1                3           14          14  ...          1.0      0.8000
# 2                1          354           7  ...          5.0      0.3552
# 3               10           16           4  ...          3.0      0.9127
# 4                8          130          52  ...          1.0      1.2511
#
# ...

# %% [markdown]
# ## Data Preparation

# %%
dataset.shape
# Out:
# (3000, 30)

# %%
#show first few rows of the code
dataset.head()
# Out:
#    TARGET    ID  DerogCnt  CollectCnt  BanruptcyInd  InqCnt06  InqTimeLast  \
# 0       1   582         3           3             0         4          0.0
# 1       1   662        15           9             0         3          1.0
# 2       1   805         0           0             0         1          5.0
# 3       1  1175         8           5             0         6          1.0
# 4       1  1373         3           1             0         9          0.0
#
#    InqFinanceCnt24  TLTimeFirst  TLTimeLast  ...  TL50UtilCnt  TLBalHCPct  \
# 0                5          117          27  ...          3.0      0.9179
# 1                3           14          14  ...          1.0      0.8000
# 2                1          354           7  ...          5.0      0.3552
# 3               10           16           4  ...          3.0      0.9127
# 4                8          130          52  ...          1.0      1.2511
#
# ...

# %%
dataset.drop('ID', axis=1)
# Out:
#       TARGET  DerogCnt  CollectCnt  BanruptcyInd  InqCnt06  InqTimeLast  \
# 0          1         3           3             0         4          0.0
# 1          1        15           9             0         3          1.0
# 2          1         0           0             0         1          5.0
# 3          1         8           5             0         6          1.0
# 4          1         3           1             0         9          0.0
# ...      ...       ...         ...           ...       ...          ...
# 2995       0         0           0             0         2          0.0
# 2996       0         0           0             0         0          NaN
# 2997       0         1           1             0         8          0.0
# 2998       0         4           4             0         2          3.0
# 2999       0         2           1             1         0         18.0
#
#       InqFinanceCnt24  TLTimeFirst  TLTimeLast  TLCnt03  ...  TL50UtilCnt  \
# ...

# %%
# Exploring the missing values
dataset.isna().sum()
# Out:
# TARGET             0
# ID                 0
# DerogCnt           0
# CollectCnt         0
# BanruptcyInd       0
# InqCnt06           0
# InqTimeLast        0
# InqFinanceCnt24    0
# TLTimeFirst        0
# TLTimeLast         0
# TLCnt03            0
# TLCnt12            0
# TLCnt24            0
# TLCnt              0
# TLSum              0
# TLMaxSum           0
# TLSatCnt           0
# TLDel60Cnt         0
# TLBadCnt24         0
# TL75UtilCnt        0
# TL50UtilCnt        0
# TLBalHCPct         0
# TLSatPct           0
# TLDel3060Cnt24     0
# TLDel90Cnt24       0
# TLDel60CntAll      0
# TLOpenPct          0
# TLBadDerogCnt      0
# TLDel60Cnt24       0
# TLOpen24Pct        0
# dtype: int64

# %%
# Filling missing values with the mean
dataset = dataset.fillna(dataset.mean())

# This is a pure data science pratice

# %% [markdown]
# ## Training the Model

# %%
y = dataset.iloc[:, 0].values
X = dataset.iloc[:,1:28].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.2)

# %%
# Data Normalization is done by using standard Scaler
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Building the Model

# %%
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression()
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = classifier.predict(X_test)

# %% [markdown]
# ## Evaluating the Model Performance

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

cm = confusion_matrix(y_pred, y_test)
print(cm)
# The confusion matrix is a table that is often used to describe
# the performance of a classification model on a set of test data for which the true values are known.


ac = accuracy_score(y_pred, y_test)
print(ac)
# Out:
# [[482  84]
#  [ 16  18]]
# 0.8333333333333334

# %% [markdown]
# ## Writing Output File

# %%
predictions = classifier.predict_proba(X_test)
predictions
# Out:
# array([[0.04056882, 0.95943118],
#        [0.93084336, 0.06915664],
#        [0.70141215, 0.29858785],
#        ...,
#        [0.9689144 , 0.0310856 ],
#        [0.48408942, 0.51591058],
#        [0.87566639, 0.12433361]])
